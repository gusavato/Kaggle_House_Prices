# %%
import pandas as pd
pd.set_option('display.max_columns', None)  
import plotly.express as px
pd.options.plotting.backend = "plotly"

# %%
test = pd.read_csv('../data/test.csv')
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
train = pd.read_csv('../data/train.csv')
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# Debemos hacer las mismas transformaciones en ambos datasets, por lo que los concatenaremos para aplicar en ambos a la vez las trasnformaciones que convengamos. Una vez terminado los volveremos a separar.

# %%
data = pd.concat([train.drop(columns='SalePrice'),test],axis=0).reset_index(drop=True)
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 2914  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2915  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2916  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2917  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2918  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2433 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
# ...

# %% [markdown]
# Hay muchos nulos. Vamos a visualizarlos

# %%
data.isna().sum()[data.isna().sum() > 0].plot.bar()
# Out:
# <div>                            <div id="5021809c-ac32-4998-af69-0a03149a5efe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5021809c-ac32-4998-af69-0a03149a5efe")) {                    Plotly.newPlot(                        "5021809c-ac32-4998-af69-0a03149a5efe",                        [{"alignmentgroup":"True","hovertemplate":"variable=0<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"v","showlegend":true,"textposition":"auto","x":["MSZoning","LotFrontage","Alley","Utilities","Exterior1st","Exterior2nd","MasVnrType","MasVnrArea","BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1","BsmtFinSF1","BsmtFinType2","BsmtFinSF2","BsmtUnfSF","Tot
# ...

# %% [markdown]
# ## Revisión de nulos
# 1. Alley

# %%
data.Alley.unique()
# Out:
# array([nan, 'Grvl', 'Pave'], dtype=object)

# %%
data.Alley.value_counts()
# Out:
# Alley
# Grvl    120
# Pave     78
# Name: count, dtype: int64

# %% [markdown]
# Según la inforamción que acompaña al dataset los valores nulos, son propiedades que no tienen Alley

# %%
data.loc[data.Alley.isna(),'Alley'] = 'No Alley'

# %%
data.Alley.value_counts()
# Out:
# Alley
# No Alley    2721
# Grvl         120
# Pave          78
# Name: count, dtype: int64

# %% [markdown]
# 2. PoolQC

# %%
data.PoolQC.unique()
# Out:
# array([nan, 'Ex', 'Fa', 'Gd'], dtype=object)

# %%
data.PoolQC.value_counts()
# Out:
# PoolQC
# Ex    4
# Gd    4
# Fa    2
# Name: count, dtype: int64

# %% [markdown]
# Según documentación los valores no nulos son sin piscina. El número de nulos es elevado de casi 3000 valores son solo 10 no nulos. Teniendo 80 campos que analizar, optaremos por eliminar esta columna, ya que demasiadas características puede aplicar mucho ruido al modelo.

# %%
data = data.drop(columns='PoolQC')

# %% [markdown]
# 3. MiscFeature

# %%
data.MiscFeature.unique()
# Out:
# array([nan, 'Shed', 'Gar2', 'Othr', 'TenC'], dtype=object)

# %%
data.MiscFeature.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2919 entries, 0 to 2918
# Series name: MiscFeature
# Non-Null Count  Dtype
# --------------  -----
# 105 non-null    object
# dtypes: object(1)
# memory usage: 22.9+ KB

# %%
data.MiscFeature.value_counts()
# Out:
# MiscFeature
# Shed    95
# Gar2     5
# Othr     4
# TenC     1
# Name: count, dtype: int64

# %% [markdown]
# Lo catalogaremos como una categoría de 1 y 0. Si tiene MiscFeature = 1 si no 0. Lo pasamos a int, ya que tenga una cualidad extra la casa tendrá más valor

# %%
data.loc[~(data.MiscFeature.isna()),'MiscFeature'] = 1

# %%
data.loc[data.MiscFeature.isna(),'MiscFeature'] = 0

# %%
data.MiscFeature = data.MiscFeature.astype('int8')

# %%
data.MiscFeature.value_counts()
# Out:
# MiscFeature
# 0    2814
# 1     105
# Name: count, dtype: int64

# %% [markdown]
# 4. Fence

# %%
data.Fence.unique()
# Out:
# array([nan, 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object)

# %%
data.Fence.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2919 entries, 0 to 2918
# Series name: Fence
# Non-Null Count  Dtype
# --------------  -----
# 571 non-null    object
# dtypes: object(1)
# memory usage: 22.9+ KB

# %%
data.Fence.value_counts()
# Out:
# Fence
# MnPrv    329
# GdPrv    118
# GdWo     112
# MnWw      12
# Name: count, dtype: int64

# %% [markdown]
# Actuamos de manera similar a la anterior, y calificamos con 1 si tiene Fence y 0 si no tiene. No podemos distinguir sin good wood es mejor que good privicy.

# %%
data.loc[~(data.Fence.isna()),'Fence'] = 1
data.loc[data.Fence.isna(),'Fence'] = 0
data.Fence = data.Fence.astype('int8')

# %%
data.Fence.value_counts()
# Out:
# Fence
# 0    2348
# 1     571
# Name: count, dtype: int64

# %% [markdown]
# 5. MassVnrType

# %% [markdown]
# Los valores nulos según documentación significa que no tienen revistimiento

# %%
data.MasVnrType = data.MasVnrType.fillna('No mass')

# %%
data.MasVnrType.value_counts()
# Out:
# MasVnrType
# No mass    1766
# BrkFace     879
# Stone       249
# BrkCmn       25
# Name: count, dtype: int64

# %% [markdown]
# 6. FireplaceQu

# %% [markdown]
# Según documentación, los valores nulos son que no posee fireplace

# %%
data.FireplaceQu = data.FireplaceQu.fillna(0)

# %%
data.FireplaceQu = data.FireplaceQu.replace({'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1})

# %%
data.FireplaceQu = data.FireplaceQu.astype('int8')

# %% [markdown]
# 7. LotFrontage

# %% [markdown]
# Los valores nulos son aquellas viviendas que no tienen comunicación directa con la calle (pisos). Por lo tanto los valores nulos los podemos igualar a cero

# %%
data.LotFrontage = data.LotFrontage.fillna(0)

# %% [markdown]
# 8. Garage Columns

# %% [markdown]
# Vemos que hay muchas columnas realacionadas con el garage que tienen la misma cantidad de nulos (159). Revisando la documentación vemos que los valores nulos son aquellos que no tienen garaje. Por lo que los rellenaremos con esta información. Revisaremos también aquellas columnas categóricas que nos interese pasar a numérica, con le objetivo de mejorar la regresión

# %%
# GarageType. La mantenemos categórica
data.GarageType = data.GarageType.fillna('NoGar')

# %%
# GarageYrBlt. Año de construcción del garaje
data.GarageYrBlt.describe()
# Out:
# count    2760.000000
# mean     1978.113406
# std        25.574285
# min      1895.000000
# 25%      1960.000000
# 50%      1979.000000
# 75%      2002.000000
# max      2207.000000
# Name: GarageYrBlt, dtype: float64

# %% [markdown]
# Para rellenar esta columna optaremos por establecer este valor como un outlier. No es conveniente rellenarlos con 0 porque es un número bastante menor que la media, y puede afectar negativamente al rendimiento del modelo. Así que las casas que no tienen garaje, estableceremos el valor de año de construcción (ficiticio) como media-3sigma

# %%
data.GarageYrBlt = data.GarageYrBlt.fillna(data.GarageYrBlt.describe()['mean']-3*data.GarageYrBlt.describe()['std'])

# %%
data.GarageYrBlt.sort_values(ascending=False)
# Out:
# 2592    2207.0
# 378     2010.0
# 819     2010.0
# 987     2010.0
# 1608    2010.0
#          ...
# 2250    1900.0
# 2757    1900.0
# 1530    1900.0
# 1602    1896.0
# 2217    1895.0
# Name: GarageYrBlt, Length: 2919, dtype: float64

# %%
data.iloc[2590:2593,:]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street     Alley  \
# 2590  2591          20       RL        149.0    19958   Pave  No Alley
# 2591  2592          20       RL         67.0     8368   Pave  No Alley
# 2592  2593          20       RL         68.0     8298   Pave  No Alley
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 2590      Reg         Lvl    AllPub    Inside       Gtl       Timber
# 2591      IR1         HLS    AllPub    Inside       Gtl       Timber
# 2592      IR1         HLS    AllPub    Inside       Gtl       Timber
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 2590       Norm       Norm     1Fam     1Story            6            8
# 2591       Norm       Norm     1Fam     1Story            7            5
# 2592       Norm       Norm     1Fam     1Story            8            5
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# ...

# %% [markdown]
# Observamos que el indice 2592 tiene un valor de año de construcción del garaje de 2207. Obviemente es un error. Observamos que el año de construcción de la casa es de 2007, por lo que sustituiremos dicho valor incorrecto por 2007

# %%
data.loc[2592,'GarageYrBlt'] = 2007

# %%
data.GarageYrBlt.describe()
# Out:
# count    2919.000000
# mean     1973.865741
# std        30.057196
# min      1895.000000
# 25%      1957.000000
# 50%      1977.000000
# 75%      2001.000000
# max      2010.000000
# Name: GarageYrBlt, dtype: float64

# %%
# GarageFinish
data.GarageFinish.unique()
# Out:
# array(['RFn', 'Unf', 'Fin', nan], dtype=object)

# %% [markdown]
# Podemos pasarlo a numérico

# %%
data.GarageFinish = data.GarageFinish.fillna(0)
data.GarageFinish.replace({'Fin':3,'RFn':2,'Unf':1},inplace=True)
data.GarageFinish = data.GarageFinish.astype('int8')

# %%
# GarageQual
data.GarageQual.unique()
# Out:
# array(['TA', 'Fa', 'Gd', nan, 'Ex', 'Po'], dtype=object)

# %% [markdown]
# Procedemos de igual manera

# %%
data.GarageQual = data.GarageQual.fillna(0)
data.GarageQual.replace({'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1},inplace=True)
data.GarageQual = data.GarageQual.astype('int8')

# %%
# GarageCond

# %%
data.GarageCond.unique()
# Out:
# array(['TA', 'Fa', nan, 'Gd', 'Po', 'Ex'], dtype=object)

# %% [markdown]
# Idem

# %%
data.GarageCond = data.GarageCond.fillna(0)
data.GarageCond.replace({'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1},inplace=True)
data.GarageCond = data.GarageCond.astype('int8')

# %% [markdown]
# 9. Basement columns

# %% [markdown]
# Hay que revisar los valores de estas columnas, ya que según la documentación los nulos son casas que no tienen sótano. Pero hay algunas columnas que tienen 81 nulos y otras 79, por lo que alguna información puede estar incorrecta

# %%
data[(data.BsmtCond.isna()) & (data.BsmtQual.notna())][['BsmtCond','BsmtQual','BsmtFinType1','TotalBsmtSF']]
# Out:
#      BsmtCond BsmtQual BsmtFinType1  TotalBsmtSF
# 2040      NaN       Gd          GLQ       1426.0
# 2185      NaN       TA          BLQ       1127.0
# 2524      NaN       TA          ALQ        995.0

# %% [markdown]
# ### Primeras impresiones:
# - <ins>Id</ins>: Borraremos esta columna es solo identificativa de la línea
# - <ins>MSSubClass</ins>: Esta columna está clasificada como int, y define la categoría del edificio. Se deberá pasar a string o otro tipo para que el valor numérico no afecte a la regresión
